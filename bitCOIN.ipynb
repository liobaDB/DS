# %% [markdown]
# <a href="https://colab.research.google.com/github/liobaDB/DS/blob/main/bitCOIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import numpy as np  # useful for many scientific computing in Python
##import pandas as pd # primary data structure library
##from google.colab import files
#files.download('bitcoins.xlsx')

import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/Colab Notebooks/bitcoins.csv"
df = pd.read_csv(path)

df.head(5)

# %%
#import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
  
x = []
y = []
  
with open('/content/drive/MyDrive/Colab Notebooks/bitcoins.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter = ',')
    count = 0  
    for row in plots:
        if (count > 4390):
          x.append(row[0])
          y.append(row[8])
        count += 1 
        

  
#plt.bar(x, y, color = 'g', width = 0.72, label = "Age")
#plt.bar(x, y, color = 'g')
#plt.plot(x, y, color = 'g', linestyle = 'dashed',
#         marker = 'o',label = "price")
plt.plot(x, y, color = 'g')

#plt.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
plt.xlabel('Year')

plt.xticks(rotation=90)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Ages of different persons')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/bitcoins100.csv')
plt.xticks(rotation=90)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
df['Date'] = pd.to_datetime(df['Date'])

plt.bar(df['Date'], df['Price'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/BTCfrom2015.csv')
plt.xticks(rotation=90)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
df['Date'] = pd.to_datetime(df['Date'])

plt.bar(df['Date'], df['Close'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/BTCfrom2015.csv')
plt.xticks(rotation=90)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
df['Date'] = pd.to_datetime(df['Date'])

plt.plot(df['Date'], df['Close'])

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
